# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Diabetes.csv")

# %%
x = df['bmi']
y = df['glucose']
scatterPlot = plt.scatter(x,y)

# %%
linePlot = plt.plot(x) #
linePlot2values = plt.plot(x,y)  # dif b/w the 2 valuess

# %%
histogram = plt.hist(x)

# %%
bar = plt.bar(x, height = 17, color = 'pink')

# %%
pie = plt.pie(df['diabetes'])

# %%
import seaborn as sns

# %%
sns.lineplot(x = x, y = y, data = df)
# Out:
# <Axes: xlabel='bmi', ylabel='glucose'>

# %%
a = df['age']
b = df['bmi']

# %%
sns.scatterplot(x = a, y = b, data = df)
# Out:
# <Axes: xlabel='age', ylabel='bmi'>

# %%
sns.barplot(x = a, y = b, data = df)
# Out:
# <Axes: xlabel='age', ylabel='bmi'>

# %%
sns.displot(x = a, y = b, data = df, color = 'pink')

# %%
sns.displot(x = b, data = df)

# %%
sns.pairplot(data = df)

# %%
sns.pairplot(data = df, hue = 'diabetes')

# %%
sns.boxplot(x = a, y = b, data = df)

# %%
sns.boxenplot(x = a, y = b, data = df)
